# %%
import glob
import cv2
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter

from torchsummary import summary

import albumentations as A
from albumentations.pytorch import ToTensorV2

import numpy as np
import xml.etree.ElementTree as ET

from copy import deepcopy

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
root_dir = '/kaggle/input/stanford-dogs-dataset'
img_dir = '/images/Images/'
annot_dir = '/annotations/Annotation/'

# %%
import os

labels_map = {}
for i, item in enumerate(os.listdir(root_dir + img_dir)):
    sub_folder = os.path.join(root_dir + img_dir, item)
    labels_map[sub_folder.split('-', maxsplit=3)[-1]] = i

labels_map_lst = list(labels_map.items())

# %%
def img_crop(annot_path, img):
    tree = ET.parse(annot_path)
    obj = tree.find('./object')
    bndbox = obj.find('bndbox')

    # 강아지 종류
    species = obj.find('name').text

    # 이미지에서의 강아지 위치
    xmin = int(bndbox.find('xmin').text)
    ymin = int(bndbox.find('ymin').text)
    xmax = int(bndbox.find('xmax').text)
    ymax = int(bndbox.find('ymax').text)

    cropped_img = img[ymin:ymax, xmin:xmax]
    
    label = labels_map.get(species)

    return label, cropped_img

# %%
class DogsDataset(Dataset):
    def __init__(self, annot_dir, img_dir, transform=None):
        annot_dir = glob.glob(root_dir + annot_dir + '*/*')
        img_dir = glob.glob(root_dir + img_dir + '*/*.jpg')
        self.annot_dir = sorted(annot_dir)
        self.img_dir = sorted(img_dir)
        self.transform = transform
        
    def __len__(self):
        return len(self.img_dir)
        
    def __getitem__(self, idx):
        annot_path = self.annot_dir[idx]
        img_path = self.img_dir[idx]
        
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        
        label, img = img_crop(annot_path, img)
        if self.transform is not None:
            img = self.transform(image=img)
            img['label'] = label
            return img

        sample = {'image': img, 'label': label}
        return sample

# %%
transformer = A.Compose([
    A.Resize(224,224),
    A.OneOf([
        A.VerticalFlip(),
        A.HorizontalFlip(),
        A.RandomBrightnessContrast(),
    ], p=1),
    A.Normalize(),
    ToTensorV2()
])

# %%
total_dataset = DogsDataset(annot_dir=annot_dir,
                           img_dir=img_dir,
                           transform=transformer)

# %%
total_dataset[12]
# Out:
# {'image': tensor([[[-1.0562, -1.5528, -0.7308,  ...,  1.4269,  1.4269,  1.5639],
#           [-1.6898, -0.5767,  0.0912,  ...,  1.6324,  1.6324,  1.5982],
#           [-0.3541,  0.1426, -0.5767,  ...,  1.4440,  1.4612,  1.5982],
#           ...,
#           [-1.6727, -1.5699, -1.4500,  ...,  1.1358,  1.3413,  1.4440],
#           [-1.5014, -1.4158, -1.3644,  ...,  0.0741,  0.3309,  0.6049],
#           [-1.3815, -1.3130, -1.3130,  ..., -0.2513, -0.2856, -0.2513]],
#
#          [[-1.2479, -1.7381, -0.8978,  ...,  1.9209,  1.9209,  2.0609],
#           [-1.8606, -0.7577, -0.0749,  ...,  2.1310,  2.1310,  2.0959],
#           [-0.5301, -0.0224, -0.7577,  ...,  1.9384,  1.9559,  2.0959],
#           ...,
#           [-1.9307, -1.8081, -1.7031,  ...,  1.0630,  1.2731,  1.3782],
#           [-1.7556, -1.7031, -1.6506,  ..., -0.0749,  0.1702,  0.4678],
#           [-1.6681, -1.6506, -1.6506,  ..., -0.4426, -0.4951, -0.4601]],
#
#          [[-1.3513, -1.6302, -0.8458,  ...,  2.2740,  2.2566,  2.3960],
#           [-1.6999, -0.8110, -0.1835,  ...,  2.4657,  2.4657,  2.4308],
#           [-0.6541, -0.1487, -0.8284,  ...,  2.2740,  2.2914,  2.4308],
#           ...,
#           [-1.7870, -1.6999, -1.5953,  ...,  1.2282,  1.4548,  1.5594],
#           [-1.6476, -1.5779, -1.5256,  ...,  0.0082,  0.2871,  0.5834],
#           [-1.5430, -1.5081, -1.5081,  ..., -0.3753, -0.3927, -0.3578]]]),
#  'label': 71}

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import Subset

total_label = [data['label'] for data in total_dataset]

trainset_idx, testset_idx = train_test_split(range(len(total_dataset)),
                test_size=0.2, random_state=42, shuffle=True, stratify=total_label)

train_set_ = Subset(total_dataset, trainset_idx)

train_label = [data['label'] for data in train_set_]

trainset_idx, validset_idx = train_test_split(range(len(trainset_idx)),
                test_size=0.2, random_state=42, shuffle=True, stratify=train_label)

# %%
train_set = Subset(train_set_, trainset_idx)
test_set = Subset(total_dataset, testset_idx)
valid_set = Subset(train_set_, validset_idx)

# %% [markdown]
# # 시각화

# %%
figure, axes = plt.subplots(nrows=2, ncols=3, figsize=(10, 6))
axes = axes.flatten()

for i in range(6):
    rand_i = np.random.randint(0, len(total_dataset))
    sample = total_dataset[rand_i]
    image = sample['image'].permute(1, 2, 0)
    label = sample['label']
    
    mean=torch.tensor([0.485, 0.456, 0.406]) 
    std=torch.tensor([0.229, 0.224, 0.225])
    image.mul_(std)
    image.add_(mean)
    
    axes[i].axis('off')
    #print(image.shape)
    axes[i].imshow(image)
    axes[i].set_title('Sample #{}'.format(label))

# %% [markdown]
# # 데이터 적재

# %%
batch_size = 16
trainloader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
validloader = DataLoader(valid_set, batch_size=batch_size, shuffle=False)
testloader = DataLoader(test_set, batch_size=batch_size, shuffle=False)

# %%
train_iter = iter(trainloader)
batch = next(train_iter)
batch['image'].size(), len(batch['label'])
# Out:
# (torch.Size([16, 3, 224, 224]), 16)

# %% [markdown]
# # 모델 생성

# %%
import torch.nn as nn # 파이토치에서 제공하는 다양한 계층 (Linear Layer, ....)
import torch.optim as optim # 옵티마이저 (경사하강법...)
import torch.nn.functional as F # 파이토치에서 제공하는 함수(활성화 함수...)

# %%
class ConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels, **kwargs):
        super(ConvBlock, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, **kwargs)
        self.batchnorm = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU()
        
    def forward(self, x):
        x = self.conv(x)
        x = self.batchnorm(x)
        x = self.relu(x)
        return x

# %%
class Inception(nn.Module):
    def __init__(self, in_channels, out1_1, out3_3_r, out3_3, out5_5_r, out5_5, out_pool):
        super(Inception, self).__init__()
        self.branch1 = ConvBlock(in_channels, out1_1, kernel_size=1, stride=1, padding=0)
        
        self.branch2 = nn.Sequential(
            ConvBlock(in_channels, out3_3_r, kernel_size=1, stride=1, padding=0),
            ConvBlock(out3_3_r, out3_3, kernel_size=3, stride=1, padding=1)            
        )
        
        self.branch3 = nn.Sequential(
            ConvBlock(in_channels, out5_5_r, kernel_size=1, stride=1, padding=0),
            ConvBlock(out5_5_r, out5_5, kernel_size=5, stride=1, padding=2)
        )
        
        self.branch4 = nn.Sequential(
            nn.MaxPool2d(kernel_size=3, stride=1, padding=1),
            ConvBlock(in_channels, out_pool, kernel_size=1, stride=1, padding=0)
        )
        
    def forward(self, x):
        x1 = self.branch1(x)
        x2 = self.branch2(x)
        x3 = self.branch3(x)
        x4 = self.branch4(x)
        return torch.cat([x1,x2,x3,x4], dim=1)

# %%
class GoogLeNet(nn.Module):
    def __init__(self):
        super().__init__()
        
        self.conv1 = ConvBlock(in_channels=3, out_channels=64, kernel_size=7, stride=2, padding=3)
        self.maxpool1 = nn.MaxPool2d(kernel_size=3, stride=2, padding=1, ceil_mode=True)
        self.conv2 = ConvBlock(in_channels=64, out_channels=64, kernel_size=1, stride=1, padding=0)
        self.conv3 = ConvBlock(in_channels=64, out_channels=192, kernel_size=3, stride=1, padding=1)
        self.maxpool2 = nn.MaxPool2d(kernel_size=3, stride=2, ceil_mode=True)
        
        
        self.inception_3a = Inception(192, 64, 96, 128, 16, 32, 32)
        self.inception_3b = Inception(256, 128, 128, 192, 32, 96, 64)
        self.max_3 = nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        
        self.inception_4a = Inception(480, 192,96,208,16,48,64)
        self.inception_4b = Inception(512,160,112,224,24,64,64)
        self.inception_4c = Inception(512,128,128,256,24,64,64)
        self.inception_4d = Inception(512,112,144,288,32,64,64)
        self.inception_4e = Inception(528,256,160,320,32,128,128)
        self.max_4 = nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        
        self.inception_5a = Inception(832,256,160,320,32,128,128)
        self.inception_5b = Inception(832,384,192,384,48,128,128)
        self.avg = nn.AvgPool2d(kernel_size=7, stride=1)
        self.lin = nn.Linear(in_features=1024, out_features=120)

    
    def forward(self, x):
        x = self.conv1(x)
        x = F.dropout(x, 0.4)
        x = self.maxpool1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = F.dropout(x, 0.4)
        x = self.maxpool2(x)
        
        
        x = self.inception_3a(x)
        x = self.inception_3b(x)
        x = F.dropout(x, 0.4)
        x = self.max_3(x)
        
        x = self.inception_4a(x)
        x = self.inception_4b(x)
        x = self.inception_4c(x)
        x = self.inception_4d(x)
        x = self.inception_4e(x)
        x = F.dropout(x, 0.4)
        x = self.max_4(x)
        
        x = self.inception_5a(x)
        x = self.inception_5b(x)
        x = F.dropout(x, 0.4)
        x = self.avg(x)
        
        x = F.dropout(x, 0.4)
        x = torch.flatten(x, 1)
        x = self.lin(x)
        
        return x

# %%
model = GoogLeNet()

# %%
model.to(device)
# Out:
# GoogLeNet(
#   (conv1): ConvBlock(
#     (conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#     (dropout): Dropout2d(p=0.4, inplace=False)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=True)
#   (conv2): ConvBlock(
#     (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#     (dropout): Dropout2d(p=0.4, inplace=False)
#   )
#   (conv3): ConvBlock(
#     (conv): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batchnorm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#     (dropout): Dropout2d(p=0.4, inplace=False)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception_3a): Inception(
#     (branch1): ConvBlock(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1))
#       (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout2d(p=0.4, inplace=False)
#     )
#     (branch2): Sequential(
#       (0): ConvBlock(
#         (conv): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1))
#         (batchnorm): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#       (1): ConvBlock(
#         (conv): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#     )
#     (branch3): Sequential(
#       (0): ConvBlock(
#         (conv): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1))
#         (batchnorm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#       (1): ConvBlock(
#         (conv): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (batchnorm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): ConvBlock(
#         (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1))
#         (batchnorm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#     )
#   )
#   (inception_3b): Inception(
#     (branch1): ConvBlock(
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout2d(p=0.4, inplace=False)
#     )
#     (branch2): Sequential(
#       (0): ConvBlock(
#         (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#       (1): ConvBlock(
#         (conv): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batchnorm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#     )
#     (branch3): Sequential(
#       (0): ConvBlock(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#         (batchnorm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#       (1): ConvBlock(
#         (conv): Conv2d(32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (batchnorm): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): ConvBlock(
#         (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#     )
#   )
#   (max_3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (inception_4a): Inception(
#     (branch1): ConvBlock(
#       (conv): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1))
#       (batchnorm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout2d(p=0.4, inplace=False)
#     )
#     (branch2): Sequential(
#       (0): ConvBlock(
#         (conv): Conv2d(480, 96, kernel_size=(1, 1), stride=(1, 1))
#         (batchnorm): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#       (1): ConvBlock(
#         (conv): Conv2d(96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batchnorm): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#     )
#     (branch3): Sequential(
#       (0): ConvBlock(
#         (conv): Conv2d(480, 16, kernel_size=(1, 1), stride=(1, 1))
#         (batchnorm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#       (1): ConvBlock(
#         (conv): Conv2d(16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (batchnorm): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): ConvBlock(
#         (conv): Conv2d(480, 64, kernel_size=(1, 1), stride=(1, 1))
#         (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#     )
#   )
#   (inception_4b): Inception(
#     (branch1): ConvBlock(
#       (conv): Conv2d(512, 160, kernel_size=(1, 1), stride=(1, 1))
#       (batchnorm): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout2d(p=0.4, inplace=False)
#     )
#     (branch2): Sequential(
#       (0): ConvBlock(
#         (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1))
#         (batchnorm): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#       (1): ConvBlock(
#         (conv): Conv2d(112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batchnorm): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#     )
#     (branch3): Sequential(
#       (0): ConvBlock(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1))
#         (batchnorm): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#       (1): ConvBlock(
#         (conv): Conv2d(24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): ConvBlock(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#         (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#     )
#   )
#   (inception_4c): Inception(
#     (branch1): ConvBlock(
#       (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout2d(p=0.4, inplace=False)
#     )
#     (branch2): Sequential(
#       (0): ConvBlock(
#         (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#         (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#       (1): ConvBlock(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#     )
#     (branch3): Sequential(
#       (0): ConvBlock(
#         (conv): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1))
#         (batchnorm): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#       (1): ConvBlock(
#         (conv): Conv2d(24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): ConvBlock(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#         (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#     )
#   )
#   (inception_4d): Inception(
#     (branch1): ConvBlock(
#       (conv): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1))
#       (batchnorm): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout2d(p=0.4, inplace=False)
#     )
#     (branch2): Sequential(
#       (0): ConvBlock(
#         (conv): Conv2d(512, 144, kernel_size=(1, 1), stride=(1, 1))
#         (batchnorm): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#       (1): ConvBlock(
#         (conv): Conv2d(144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batchnorm): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#     )
#     (branch3): Sequential(
#       (0): ConvBlock(
#         (conv): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#         (batchnorm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#       (1): ConvBlock(
#         (conv): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): ConvBlock(
#         (conv): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#         (batchnorm): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#     )
#   )
#   (inception_4e): Inception(
#     (branch1): ConvBlock(
#       (conv): Conv2d(528, 256, kernel_size=(1, 1), stride=(1, 1))
#       (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout2d(p=0.4, inplace=False)
#     )
#     (branch2): Sequential(
#       (0): ConvBlock(
#         (conv): Conv2d(528, 160, kernel_size=(1, 1), stride=(1, 1))
#         (batchnorm): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#       (1): ConvBlock(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batchnorm): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#     )
#     (branch3): Sequential(
#       (0): ConvBlock(
#         (conv): Conv2d(528, 32, kernel_size=(1, 1), stride=(1, 1))
#         (batchnorm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#       (1): ConvBlock(
#         (conv): Conv2d(32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): ConvBlock(
#         (conv): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1))
#         (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#     )
#   )
#   (max_4): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (inception_5a): Inception(
#     (branch1): ConvBlock(
#       (conv): Conv2d(832, 256, kernel_size=(1, 1), stride=(1, 1))
#       (batchnorm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout2d(p=0.4, inplace=False)
#     )
#     (branch2): Sequential(
#       (0): ConvBlock(
#         (conv): Conv2d(832, 160, kernel_size=(1, 1), stride=(1, 1))
#         (batchnorm): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#       (1): ConvBlock(
#         (conv): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batchnorm): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#     )
#     (branch3): Sequential(
#       (0): ConvBlock(
#         (conv): Conv2d(832, 32, kernel_size=(1, 1), stride=(1, 1))
#         (batchnorm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#       (1): ConvBlock(
#         (conv): Conv2d(32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): ConvBlock(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1))
#         (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#     )
#   )
#   (inception_5b): Inception(
#     (branch1): ConvBlock(
#       (conv): Conv2d(832, 384, kernel_size=(1, 1), stride=(1, 1))
#       (batchnorm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#       (dropout): Dropout2d(p=0.4, inplace=False)
#     )
#     (branch2): Sequential(
#       (0): ConvBlock(
#         (conv): Conv2d(832, 192, kernel_size=(1, 1), stride=(1, 1))
#         (batchnorm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#       (1): ConvBlock(
#         (conv): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (batchnorm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#     )
#     (branch3): Sequential(
#       (0): ConvBlock(
#         (conv): Conv2d(832, 48, kernel_size=(1, 1), stride=(1, 1))
#         (batchnorm): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#       (1): ConvBlock(
#         (conv): Conv2d(48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#     )
#     (branch4): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (1): ConvBlock(
#         (conv): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1))
#         (batchnorm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (dropout): Dropout2d(p=0.4, inplace=False)
#       )
#     )
#   )
#   (avg): AvgPool2d(kernel_size=7, stride=1, padding=0)
#   (lin): Linear(in_features=1024, out_features=120, bias=True)
# )

# %%
out = model(batch['image'].to(device))
out.shape
# Out:
# torch.Size([16, 120])

# %%
learning_rate = 0.0001
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=3, verbose=True)

# %%
summary(model, (3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,472
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          ConvBlock-4         [-1, 64, 112, 112]               0
#          MaxPool2d-5           [-1, 64, 57, 57]               0
#             Conv2d-6           [-1, 64, 57, 57]           4,160
#        BatchNorm2d-7           [-1, 64, 57, 57]             128
#               ReLU-8           [-1, 64, 57, 57]               0
#          ConvBlock-9           [-1, 64, 57, 57]               0
#            Conv2d-10          [-1, 192, 57, 57]         110,784
#       BatchNorm2d-11          [-1, 192, 57, 57]             384
#              ReLU-12          [-1, 192, 57, 57]               0
#         ConvBlock-13          [-1, 192, 57, 57]               0
#         MaxPool2d-14          [-1, 192, 28, 28]               0
#            Conv2d-15           [-1, 64, 28, 28]          12,352
#       BatchNorm2d-16           [-1, 64, 28, 28]             128
#              ReLU-17           [-1, 64, 28, 28]               0
#         ConvBlock-18           [-1, 64, 28, 28]               0
#            Conv2d-19           [-1, 96, 28, 28]          18,528
#       BatchNorm2d-20           [-1, 96, 28, 28]             192
#              ReLU-21           [-1, 96, 28, 28]               0
#         ConvBlock-22           [-1, 96, 28, 28]               0
#            Conv2d-23          [-1, 128, 28, 28]         110,720
#       BatchNorm2d-24          [-1, 128, 28, 28]             256
#              ReLU-25          [-1, 128, 28, 28]               0
#      BatchNorm2d-208            [-1, 320, 7, 7]             640
#             ReLU-209            [-1, 320, 7, 7]               0
#        ConvBlock-210            [-1, 320, 7, 7]               0
#           Conv2d-211             [-1, 32, 7, 7]          26,656
#      BatchNorm2d-212             [-1, 32, 7, 7]              64
#             ReLU-213             [-1, 32, 7, 7]               0
#        ConvBlock-214             [-1, 32, 7, 7]               0
#           Conv2d-215            [-1, 128, 7, 7]         102,528
#      BatchNorm2d-216            [-1, 128, 7, 7]             256
#             ReLU-217            [-1, 128, 7, 7]               0
#        ConvBlock-218            [-1, 128, 7, 7]               0
#        MaxPool2d-219            [-1, 832, 7, 7]               0
#           Conv2d-220            [-1, 128, 7, 7]         106,624
#      BatchNorm2d-221            [-1, 128, 7, 7]             256
#             ReLU-222            [-1, 128, 7, 7]               0
#        ConvBlock-223            [-1, 128, 7, 7]               0
#        Inception-224            [-1, 832, 7, 7]               0
#           Conv2d-225            [-1, 384, 7, 7]         319,872
#      BatchNorm2d-226            [-1, 384, 7, 7]             768
#             ReLU-227            [-1, 384, 7, 7]               0
#        ConvBlock-228            [-1, 384, 7, 7]               0
#           Conv2d-229            [-1, 192, 7, 7]         159,936
#      BatchNorm2d-230            [-1, 192, 7, 7]             384
#             ReLU-231            [-1, 192, 7, 7]               0
#        ConvBlock-232            [-1, 192, 7, 7]               0
#           Conv2d-233            [-1, 384, 7, 7]         663,936
#      BatchNorm2d-234            [-1, 384, 7, 7]             768
#             ReLU-235            [-1, 384, 7, 7]               0
#        ConvBlock-236            [-1, 384, 7, 7]               0
#           Conv2d-237             [-1, 48, 7, 7]          39,984
#      BatchNorm2d-238             [-1, 48, 7, 7]              96
#             ReLU-239             [-1, 48, 7, 7]               0
#        ConvBlock-240             [-1, 48, 7, 7]               0
#           Conv2d-241            [-1, 128, 7, 7]         153,728
#      BatchNorm2d-242            [-1, 128, 7, 7]             256
#             ReLU-243            [-1, 128, 7, 7]               0
#        ConvBlock-244            [-1, 128, 7, 7]               0
#        MaxPool2d-245            [-1, 832, 7, 7]               0
#           Conv2d-246            [-1, 128, 7, 7]         106,624
#      BatchNorm2d-247            [-1, 128, 7, 7]             256
#             ReLU-248            [-1, 128, 7, 7]               0
#        ConvBlock-249            [-1, 128, 7, 7]               0
#        Inception-250           [-1, 1024, 7, 7]               0
#        AvgPool2d-251           [-1, 1024, 1, 1]               0
#           Linear-252                  [-1, 120]         123,000
# ================================================================
# Total params: 6,111,112
# Trainable params: 6,111,112
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 119.64
# Params size (MB): 23.31
# Estimated Total Size (MB): 143.53
# ----------------------------------------------------------------

# %% [markdown]
# # 모델 학습

# %%
def validate(model, validloader, loss_fn):
    total = 0   
    correct = 0
    valid_loss = 0
    valid_accuracy = 0

  
    with torch.no_grad():
        for batch in validloader:
            images=batch['image'].to(device)
            labels=batch['label']
            labels = torch.Tensor(labels).to(device)

            logit = model(images) 
            _, preds = torch.max(logit, 1)
            correct += int((preds == labels).sum())
            total += labels.shape[0]

            loss = loss_fn(logit, labels)
            valid_loss += loss.item()

        valid_accuracy = correct / total
  
    return valid_loss, valid_accuracy

# %%
writer = SummaryWriter()

# %%
def train_loop(model, trainloader, loss_fn, epochs, optimizer):
    steps = 0
    steps_per_epoch = len(trainloader)
    min_loss = np.inf
    max_accuracy = -np.inf
    trigger = 0
    p = 10


    for epoch in range(epochs):
        model.train()
        train_loss = 0

        for batch in trainloader:
            images=batch['image'].to(device)
            labels=batch['label']
            labels = torch.Tensor(labels).to(device)
            
            steps+=1
                      
            predict = model(images)
            loss = loss_fn(predict, labels)

            optimizer.zero_grad()
            loss.backward()

            optimizer.step()

            train_loss += loss.item()

            if (steps % steps_per_epoch) == 0:
                model.eval()
                valid_loss, valid_accuracy = validate(model, validloader, loss_fn)    
                
                print('Epoch : {}/{}.......'.format(epoch+1, epochs),            
                    'Train Loss : {:.3f}'.format(train_loss/len(trainloader)), 
                    'Valid Loss : {:.3f}'.format(valid_loss/len(validloader)), 
                    'Valid Accuracy : {:.3f}'.format(valid_accuracy))

                writer.add_scalar('Train Loss', train_loss/len(trainloader), epoch+1)
                writer.add_scalar('Valid Loss', valid_loss/len(validloader), epoch+1)
                writer.add_scalars('Train Loss and Valid Loss',
                                    {'Train' : train_loss/len(trainloader),
                                    'Valid' : valid_loss/len(validloader)}, epoch+1)
                writer.add_scalar('Valid Accuracy', valid_accuracy, epoch+1)

                if (valid_loss < min_loss) and (valid_accuracy >= max_accuracy):
                    print('save ckpt')
                    min_loss = valid_loss
                    max_accuracy = valid_accuracy

                    best_model = deepcopy(model)
                    torch.save(best_model.state_dict(), 'best_ckpt_google_batch_16_V2.pth')

                
                # --- early stopping --- #
                if valid_loss > min_loss:
                    print('----trigger----', trigger+1)
                    trigger += 1
                    if trigger > p:
                        print('Early Stopping')
                        print('training loop is finished')
                        writer.flush()
                        return 
                else:
                    trigger = 0
                    min_loss = valid_loss
                    
                scheduler.step(valid_loss)
                    
    writer.flush()

# %%
epochs = 150
# %time train_loop(model, trainloader, loss_fn, epochs, optimizer)
writer.close()
# Out:
# Epoch : 1/150....... Train Loss : 4.458 Valid Loss : 4.218 Valid Accuracy : 0.056
# save ckpt
# Epoch : 2/150....... Train Loss : 4.060 Valid Loss : 4.034 Valid Accuracy : 0.073
# save ckpt
# Epoch : 3/150....... Train Loss : 3.821 Valid Loss : 3.700 Valid Accuracy : 0.119
# save ckpt
# Epoch : 4/150....... Train Loss : 3.610 Valid Loss : 3.431 Valid Accuracy : 0.153
# save ckpt
# Epoch : 5/150....... Train Loss : 3.414 Valid Loss : 3.243 Valid Accuracy : 0.180
# save ckpt
# Epoch : 6/150....... Train Loss : 3.237 Valid Loss : 3.225 Valid Accuracy : 0.198
# save ckpt
# Epoch : 7/150....... Train Loss : 3.050 Valid Loss : 3.314 Valid Accuracy : 0.193
# ----trigger---- 1
# Epoch : 8/150....... Train Loss : 2.880 Valid Loss : 2.914 Valid Accuracy : 0.253
# save ckpt
# Epoch : 9/150....... Train Loss : 2.711 Valid Loss : 2.725 Valid Accuracy : 0.297
# save ckpt
# Epoch : 10/150....... Train Loss : 2.580 Valid Loss : 2.501 Valid Accuracy : 0.323
# save ckpt
# Epoch : 11/150....... Train Loss : 2.436 Valid Loss : 2.477 Valid Accuracy : 0.336
# save ckpt
# Epoch : 12/150....... Train Loss : 2.320 Valid Loss : 2.402 Valid Accuracy : 0.357
# save ckpt
# Epoch : 13/150....... Train Loss : 2.176 Valid Loss : 2.274 Valid Accuracy : 0.379
# save ckpt
# Epoch : 14/150....... Train Loss : 2.050 Valid Loss : 2.188 Valid Accuracy : 0.411
# save ckpt
# Epoch : 15/150....... Train Loss : 1.980 Valid Loss : 2.117 Valid Accuracy : 0.420
# save ckpt
# Epoch : 16/150....... Train Loss : 1.886 Valid Loss : 2.019 Valid Accuracy : 0.449
# save ckpt
# Epoch : 17/150....... Train Loss : 1.790 Valid Loss : 1.985 Valid Accuracy : 0.462
# save ckpt
# Epoch : 18/150....... Train Loss : 1.716 Valid Loss : 2.007 Valid Accuracy : 0.465
# ----trigger---- 1
# Epoch : 19/150....... Train Loss : 1.623 Valid Loss : 1.995 Valid Accuracy : 0.444
# ----trigger---- 2
# Epoch : 20/150....... Train Loss : 1.553 Valid Loss : 1.978 Valid Accuracy : 0.457
# Epoch : 21/150....... Train Loss : 1.465 Valid Loss : 1.884 Valid Accuracy : 0.484
# save ckpt
# Epoch : 22/150....... Train Loss : 1.405 Valid Loss : 1.851 Valid Accuracy : 0.497
# save ckpt
# Epoch : 23/150....... Train Loss : 1.339 Valid Loss : 1.911 Valid Accuracy : 0.475
# ----trigger---- 1
# Epoch : 24/150....... Train Loss : 1.293 Valid Loss : 1.833 Valid Accuracy : 0.493
# Epoch : 25/150....... Train Loss : 1.233 Valid Loss : 1.886 Valid Accuracy : 0.492
# ----trigger---- 1
# Epoch : 26/150....... Train Loss : 1.190 Valid Loss : 1.766 Valid Accuracy : 0.515
# save ckpt
# Epoch : 27/150....... Train Loss : 1.115 Valid Loss : 1.766 Valid Accuracy : 0.517
# ----trigger---- 1
# Epoch : 28/150....... Train Loss : 1.085 Valid Loss : 1.791 Valid Accuracy : 0.522
# ----trigger---- 2
# Epoch : 29/150....... Train Loss : 1.034 Valid Loss : 1.780 Valid Accuracy : 0.515
# ----trigger---- 3
# Epoch : 30/150....... Train Loss : 0.980 Valid Loss : 1.782 Valid Accuracy : 0.516
# ----trigger---- 4
# Epoch 00030: reducing learning rate of group 0 to 1.0000e-05.
# Epoch : 31/150....... Train Loss : 0.727 Valid Loss : 1.545 Valid Accuracy : 0.576
# save ckpt
# Epoch : 32/150....... Train Loss : 0.654 Valid Loss : 1.534 Valid Accuracy : 0.584
# save ckpt
# Epoch : 33/150....... Train Loss : 0.611 Valid Loss : 1.516 Valid Accuracy : 0.585
# save ckpt
# Epoch : 34/150....... Train Loss : 0.594 Valid Loss : 1.493 Valid Accuracy : 0.582
# Epoch : 35/150....... Train Loss : 0.578 Valid Loss : 1.535 Valid Accuracy : 0.583
# ----trigger---- 1
# Epoch : 36/150....... Train Loss : 0.554 Valid Loss : 1.547 Valid Accuracy : 0.583
# ----trigger---- 2
# Epoch : 37/150....... Train Loss : 0.547 Valid Loss : 1.529 Valid Accuracy : 0.578
# ----trigger---- 3
# Epoch : 38/150....... Train Loss : 0.515 Valid Loss : 1.525 Valid Accuracy : 0.582
# ----trigger---- 4
# Epoch 00038: reducing learning rate of group 0 to 1.0000e-06.
# Epoch : 39/150....... Train Loss : 0.502 Valid Loss : 1.516 Valid Accuracy : 0.584
# ----trigger---- 5
# Epoch : 40/150....... Train Loss : 0.499 Valid Loss : 1.544 Valid Accuracy : 0.578
# ----trigger---- 6
# Epoch : 41/150....... Train Loss : 0.493 Valid Loss : 1.534 Valid Accuracy : 0.581
# ----trigger---- 7
# Epoch : 42/150....... Train Loss : 0.483 Valid Loss : 1.534 Valid Accuracy : 0.577
# ----trigger---- 8
# Epoch 00042: reducing learning rate of group 0 to 1.0000e-07.
# Epoch : 43/150....... Train Loss : 0.486 Valid Loss : 1.512 Valid Accuracy : 0.587
# ----trigger---- 9
# Epoch : 44/150....... Train Loss : 0.480 Valid Loss : 1.551 Valid Accuracy : 0.578
# ----trigger---- 10
# Epoch : 45/150....... Train Loss : 0.487 Valid Loss : 1.509 Valid Accuracy : 0.585
# ----trigger---- 11
# Early Stopping
# training loop is finished
# CPU times: user 1h 58min, sys: 17min 1s, total: 2h 15min 1s
# Wall time: 2h 46min 21s

# %% [markdown]
# # 모델 예측

# %%
test_iter = iter(testloader)

# %%
batch = next(test_iter)

# %%
images, labels = batch['image'].to(device), batch['label'].to(device)
print(images.size(), labels.size())

rnd_idx = 3
print(images[rnd_idx].shape, labels[rnd_idx])
# Out:
# torch.Size([16, 3, 224, 224]) torch.Size([16])
# torch.Size([3, 224, 224]) tensor(47, device='cuda:0')

# %%
model.eval()
with torch.no_grad():
    logit = model(images[rnd_idx].unsqueeze(0))
pred = logit.max(dim=1)[1]
print(pred == labels[rnd_idx])
# Out:
# tensor([True], device='cuda:0')

# %%
images.shape
# Out:
# torch.Size([16, 3, 224, 224])

# %%
print("pred:", pred, "labels:", labels[rnd_idx])

images = images[rnd_idx].permute(1, 2, 0).cpu()
mean=torch.tensor([0.485, 0.456, 0.406]) 
std=torch.tensor([0.229, 0.224, 0.225])
images.mul_(std)
images.add_(mean)
print(images.shape)
plt.imshow(images)
# Out:
# pred: tensor([47], device='cuda:0') labels: tensor(47, device='cuda:0')
# torch.Size([224, 224, 3])

# %%
def evaluation(model, testloader, loss_fn):
    total = 0   
    correct = 0
    test_loss = 0
    test_accuracy = 0

    with torch.no_grad():
        for batch in testloader:
            images, labels = batch['image'].to(device), batch['label'].to(device)

            logit = model(images)
            _, preds = torch.max(logit, 1)

            correct += int((preds == labels).sum())
            total += labels.shape[0]

            loss = loss_fn(logit, labels)
            test_loss += loss.item()
            
        test_accuracy = correct / total
   
        print('Test Loss : {:.3f}'.format(test_loss/len(testloader)), 
            'Test Accuracy : {:.3f}'.format(test_accuracy))

model.eval()
evaluation(model, testloader, loss_fn)
# Out:
# Test Loss : 1.553 Test Accuracy : 0.577

# %% [markdown]
# # 모델 저장 및 불러오기

# %%
torch.save(model.state_dict(), 'last_ckpt_google_batch_16_V2.pth')
# Out:
# hello

# %%
last_state_dict = torch.load('last_ckpt_google_batch_16_V2.pth')

# %%
last_model = GoogLeNet()
last_model.to(device)
last_model.load_state_dict(last_state_dict)
# Out:
# <All keys matched successfully>

# %%
last_model.eval()
evaluation(last_model, testloader, loss_fn)
# Out:
# Test Loss : 1.568 Test Accuracy : 0.580

# %%
best_state_dict = torch.load('best_ckpt_google_batch_16_V2.pth')
best_model = GoogLeNet()
best_model.to(device)
best_model.load_state_dict(best_state_dict)
# Out:
# <All keys matched successfully>

# %%
best_model.eval()
evaluation(best_model, testloader, loss_fn)
# Out:
# Test Loss : 1.537 Test Accuracy : 0.576
